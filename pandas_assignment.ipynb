# %% [markdown]
# <a href="https://colab.research.google.com/github/patilhumesh88-spec/ASSIGNMENT/blob/main/pandas_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = {
      'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
      'Age': [24, 27, 22, 32, 29],
      'Department': ['HR', 'Finance', 'IT', 'Marketing', 'HR'],
      'Salary': [45000, 54000, 50000, 62000, 47000]}

# %%
#print the first five rows of the dataFrame
display(df.head())
# Out:
#       Name  Age   Department  Salary   Bonus
# 0    Alice   24           HR   50000  5000.0
# 1      Bob   27  Engineering   70000  7000.0
# 2  Charlie   32        Sales   60000  6000.0
# 3    David   29           HR   55000  5500.0
# 4      Eve   31  Engineering   75000  7500.0

# %%
#Get the summary statistics of the 'Age' and 'Salary' columns.
display(df[['Age','Salary']].describe())
# Out:
#             Age        Salary
# count   8.00000      8.000000
# mean   28.37500  62125.000000
# std     2.66927   9341.726668
# min    24.00000  50000.000000
# 25%    26.75000  54500.000000
# 50%    28.50000  61000.000000
# 75%    30.25000  70500.000000
# max    32.00000  75000.000000

# %%
#Calculate the average salary of employees in the HR department
average_hr_salary = hr_department_df['Salary'].mean()
print(f"Average salary in the HR department:{average_hr_salary:.2f}")
# Out:
# Average salary in the HR department:52666.67

# %%
# Add a new column, 'Bonus', which is 10% of the salary.
df['Bonus']=df['Salary']*0.10
display(df.head())
# Out:
#       Name  Age   Department  Salary   Bonus
# 0    Alice   24           HR   50000  5000.0
# 1      Bob   27  Engineering   70000  7000.0
# 2  Charlie   32        Sales   60000  6000.0
# 3    David   29           HR   55000  5500.0
# 4      Eve   31  Engineering   75000  7500.0

# %%
filter_df=df[(df['Age']>=25)&(df['Age']<=30)]
display(filter_df.head())
# Out:
#     Name  Age   Department  Salary   Bonus
# 1    Bob   27  Engineering   70000  7000.0
# 3  David   29           HR   55000  5500.0
# 5  Frank   26        Sales   62000  6200.0
# 6  Grace   28           HR   53000  5300.0
# 7  Heidi   30  Engineering   72000  7200.0

# %%
#Group the data by 'Department' and calculate the average salary for each department.
avg_salary_per_department=df.groupby('Department')['Salary'].mean()
display(avg_salary_per_department)
# Out:
# Department
# Engineering    72333.333333
# HR             52666.666667
# Sales          61000.000000
# Name: Salary, dtype: float64

# %%
#Sort the DataFrame by 'Salary' in ascending order and save the result to a new CSV file.
sort_df=df.sort_values(by='Salary',ascending=True)
display(sort_df.head())
# Out:
#       Name  Age Department  Salary   Bonus
# 0    Alice   24         HR   50000  5000.0
# 6    Grace   28         HR   53000  5300.0
# 3    David   29         HR   55000  5500.0
# 2  Charlie   32      Sales   60000  6000.0
# 5    Frank   26      Sales   62000  6200.0

# %%
output_filename='sortesd_employees.csv'
sort_df.to_csv(output_filename,index=False)
print(f"DataFrame sucessfully saved to {output_filename}")
# Out:
# DataFrame sucessfully saved to sortesd_employees.csv
